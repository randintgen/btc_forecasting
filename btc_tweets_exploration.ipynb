# %% [markdown]
# ## BTC/USD Dataset Exploration

# %% [markdown]
# ##### Short dataset description
# Dataset was sourced from kaggle : https://www.kaggle.com/datasets/prasoonkottarathil/btcinusd?resource=download&select=BTC-Hourly.csv. It cointains hourly historical data of the pair BTC/USD. Data are retrieved from Gemini (crypto cex). The columns of the data contain :
#
# 1) **open** price of the hourly candle
# 2) **close** price of the hourly candle
# 3) **low** price (min) of the hourly candle
# 4) **high** price (max) of the hourly candle
# 5) **volume** volume during the candle denominated in the respective currency

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Bitcoin_tweets.csv', engine="python")
df_2 = pd.read_csv('Bitcoin_tweets_dataset_2.csv', engine="python")

# %%
df = pd.concat([df, df_2]).drop_duplicates()

# %%
df.head()
# Out:
#                                   user_name    user_location  \
# 0                             DeSota Wilson      Atlanta, GA
# 1                                  CryptoND              NaN
# 2                                 Tdlmatias  London, England
# 3                      Crypto is the future              NaN
# 4  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader           Europa
#
#                                     user_description         user_created  \
# 0  Biz Consultant, real estate, fintech, startups...  2009-04-26 20:05:09
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...  2019-10-17 20:12:10
# 2  IM Academy : The best #forex, #SelfEducation, ...  2014-11-10 10:50:37
# 3  I will post a lot of buying signals for BTC tr...  2019-09-28 16:48:12
# 4  Co-founder @RENJERJerky | Forbes 30Under30 | I...  2016-02-03 13:15:55
#
#   user_followers user_friends user_favourites user_verified  \
# 0         8534.0         7605            4838         False
# 1         6769.0         1532           25483         False
# 2          128.0          332             924         False
# 3          625.0          129              14         False
# 4         1249.0         1472           10482         False
#
#                   date                                               text  \
# 0  2021-02-10 23:59:04  Blue Ridge Bank shares halted by NYSE after #b...
# 1  2021-02-10 23:58:48  😎 Today, that's this #Thursday, we will do a "...
# 2  2021-02-10 23:54:48  Guys evening, I have read this article about B...
# 3  2021-02-10 23:54:33  $BTC A big chance in a billion! Price: \487264...
# 4  2021-02-10 23:54:06  This network is secured by 9 508 nodes as of t...
#
#                                     hashtags               source is_retweet
# 0                                ['bitcoin']      Twitter Web App      False
# 1  ['Thursday', 'Btc', 'wallet', 'security']  Twitter for Android      False
# 2                                        NaN      Twitter Web App      False
# 3         ['Bitcoin', 'FX', 'BTC', 'crypto']              dlvr.it      False
# 4                                    ['BTC']      Twitter Web App      False

# %%
df.shape
# Out:
# (4865604, 13)

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df = df.dropna(subset=['date'])
df = df.reset_index(drop=True)
df = df.sort_values(by='date')

# %%
df.head()
# Out:
#              user_name               user_location  \
# 21523   Iconic Holding  Frankfurt am Main, Germany
# 21524   Iconic Holding  Frankfurt am Main, Germany
# 21522   Iconic Holding  Frankfurt am Main, Germany
# 21521   Iconic Holding  Frankfurt am Main, Germany
# 21520  Nick Doevendans    Edam-Volendam, Nederland
#
#                                         user_description         user_created  \
# 21523  Professional Crypto Asset Ventures \nhttps://t...  2021-01-05 13:22:24
# 21524  Professional Crypto Asset Ventures \nhttps://t...  2021-01-05 13:22:24
# 21522  Professional Crypto Asset Ventures \nhttps://t...  2021-01-05 13:22:24
# 21521  Professional Crypto Asset Ventures \nhttps://t...  2021-01-05 13:22:24
# 21520  Amateur historicus m.n. WW2, schrijver, muziek...  2020-06-12 16:50:07
#
#       user_followers user_friends user_favourites user_verified  \
# 21523          301.0         1075             361         False
# 21524          301.0         1075             361         False
# 21522          301.0         1075             361         False
# 21521          301.0         1075             361         False
# 21520           37.0          123             410         False
#
#                      date                                               text  \
# 21523 2021-02-05 10:52:04  2⃣   Debunking 9 #Bitcoin Myths by @Patrick_Lo...
# 21524 2021-02-05 10:52:04  📖  Weekend Read 📖\n\nKeen to learn about #cryp...
# 21522 2021-02-05 10:52:06  4⃣  🎙️ Bloomberg LP #CryptoOutlook 2021 with @...
# 21521 2021-02-05 10:52:07  5⃣   #Blockchain 50 2021 by @DelRayMan, @Forbe...
# 21520 2021-02-05 10:52:26  #reddcoin #rdd @reddcoin to the moon #altcoin ...
#
#                                                 hashtags              source  \
# 21523  ['Bitcoin', 'cryptocurrency', 'bitcoin', 'cryp...     Twitter Web App
# 21524                                         ['crypto']     Twitter Web App
# 21522  ['CryptoOutlook', 'cryptocurrency', 'bitcoin',...     Twitter Web App
# 21521  ['Blockchain', 'cryptocurrency', 'bitcoin', 'c...     Twitter Web App
# 21520  ['reddcoin', 'rdd', 'altcoin', 'turnreddcoinin...  Twitter for iPhone
#
#       is_retweet
# 21523      False
# 21524      False
# 21522      False
# 21521      False
# 21520      False

# %%
df.shape
# Out:
# (4859004, 13)

# %%
print("Starting date is :",df['date'].min())
print("Ending date is :",df['date'].max())
# Out:
# Starting date is : 2021-02-05 10:52:04
# Ending date is : 2023-03-05 23:59:56

# %%
df2 = df.copy(deep=True)

# %%
df2.columns
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet'],
#       dtype='object')

# %%
# Convert 'user_followers' column to numeric
df2['user_followers'] = pd.to_numeric(df2['user_followers'], errors='coerce')

# %%
df2[(df2['is_retweet'] == 'False') & (df2['user_followers'] > 100)].shape
# Out:
# (3180923, 13)

# %%
df3 = df2[(df2['source'].isin(['Twitter for iPhone', 'Twitter for Android'])) & (df2['is_retweet'] == 'False') & (df2['user_followers'] > 100) & (df2['user_description'].notnull())].copy(deep=True)

# %%
isinstance(df3['hashtags'].values[0], list)
# Out:
# False

# %%
# Let's assume your dataframe is named df and the column of interest is 'hashtags'
df3['hashtags'] = df3['hashtags'].apply(lambda hashtags: str(hashtags).lower())

# Filtering out rows that don't contain 'bitcoin' or 'btc'
df3 = df3[df3['hashtags'].apply(lambda hashtags: 'bitcoin' in hashtags or 'btc' in hashtags)]

# %%
df3.head()
# Out:
#            user_name user_location  \
# 21516  Youssef Fedda     Australia
# 21502        Zapumal       Colombo
# 21499      EM_CryPT0     Nederland
# 21496  Mr Fulcanelli     Argentina
# 21487   Cardano Apps           NaN
#
#                                         user_description         user_created  \
# 21516  love interesting startups, stocks and innovati...  2021-01-13 07:16:35
# 21502  NUS PhD, Lecturer at CSE, Consultant Xeptagon....  2009-06-01 09:06:54
# 21499  ▪️@CryptoBrothers5 Team ▪️💯% #Crypto▪️#BTC ▪️N...  2010-07-12 17:04:23
# 21496              be decentralized, be a smart contract  2010-08-23 20:41:38
# 21487  CardanoApps - Discover new decentralised apps ...  2020-07-25 16:10:17
#
#        user_followers user_friends user_favourites user_verified  \
# 21516          2520.0         1085             191         False
# 21502           290.0           58             569         False
# 21499         16100.0          602            1014         False
# 21496           157.0           96            8570         False
# 21487           331.0          274            1540         False
#
#                      date                                               text  \
# 21516 2021-02-05 10:58:03  @JulSwap $juld $bnb #Binance #BSC #BinanceSmar...
# 21502 2021-02-05 11:05:17  We are gaining pace with more and more institu...
# 21499 2021-02-05 11:08:30  To-do or not To-do.   #crypto #btc #Bitcoin #E...
# 21496 2021-02-05 11:10:39  Node for #Bitcoin \n\n#blockchain #BTC https:/...
# 21487 2021-02-05 11:17:53  #bitcoin #ATH is ~2x since last #ATH. #CARDANO...
#
#                                                 hashtags               source  \
# 21516  ['binance', 'bsc', 'binancesmartchain', 'btc',...  Twitter for Android
# 21502                                        ['bitcoin']  Twitter for Android
# 21499           ['crypto', 'btc', 'bitcoin', 'ethereum']   Twitter for iPhone
# 21496                   ['bitcoin', 'blockchain', 'btc']   Twitter for iPhone
# 21487  ['bitcoin', 'ath', 'ath', 'cardano', 'ada', 'a...   Twitter for iPhone
#
#       is_retweet
# 21516      False
# 21502      False
# 21499      False
# 21496      False
# 21487      False

# %%
df3.shape
# Out:
# (1140258, 13)

# %%
import re
from tqdm import tqdm

# %%
df3 = df3.reset_index(drop=True)

# %%
for i,s in enumerate(tqdm(df3['text'],position=0, leave=True)):
    text = df3.loc[i, 'text']
    text = text.replace("#", "")
    text = re.sub('https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+', '', text, flags=re.MULTILINE)
    text = re.sub('@\\w+ *', '', text, flags=re.MULTILINE)
    df3.loc[i, 'text'] = text
# Out:
# 100%|██████████| 1140258/1140258 [00:54<00:00, 20859.57it/s]

# %% [markdown]
# #### Get sentiment prediction

# %%
from transformers import AutoConfig

# Load the configuration of the model
config = AutoConfig.from_pretrained("ProsusAI/finbert")

# Get the labels
labels = [label for key, label in config.id2label.items()]

print(labels)
# Out:
# ['positive', 'negative', 'neutral']

# %%
df4 = df3

# %%
df4
# Out:
#           user_name user_location  \
# 0     Youssef Fedda     Australia
# 1           Zapumal       Colombo
# 2         EM_CryPT0     Nederland
# 3     Mr Fulcanelli     Argentina
# 4      Cardano Apps           NaN
# ...             ...           ...
# 1995   Free Bitcoin           NaN
# 1996   Free Bitcoin           NaN
# 1997      xbt_blvrg           NaN
# 1998   Free Bitcoin           NaN
# 1999   Free Bitcoin           NaN
#
#                                        user_description         user_created  \
# 0     love interesting startups, stocks and innovati...  2021-01-13 07:16:35
# 1     NUS PhD, Lecturer at CSE, Consultant Xeptagon....  2009-06-01 09:06:54
# 2     ▪️@CryptoBrothers5 Team ▪️💯% #Crypto▪️#BTC ▪️N...  2010-07-12 17:04:23
# 3                 be decentralized, be a smart contract  2010-08-23 20:41:38
# 4     CardanoApps - Discover new decentralised apps ...  2020-07-25 16:10:17
# ...                                                 ...                  ...
# 1995  #FreeBitcoin  #Bitcoin #BTC #Bitcoinmining #El...  2018-08-10 06:29:19
# 1996  #FreeBitcoin  #Bitcoin #BTC #Bitcoinmining #El...  2018-08-10 06:29:19
# 1997              I trade crypto futures and flip #BTC.  2011-11-09 16:38:56
# 1998  #FreeBitcoin  #Bitcoin #BTC #Bitcoinmining #El...  2018-08-10 06:29:19
# 1999  #FreeBitcoin  #Bitcoin #BTC #Bitcoinmining #El...  2018-08-10 06:29:19
#
#       user_followers user_friends user_favourites user_verified  \
# 0             2520.0         1085             191         False
# 1              290.0           58             569         False
# 2            16100.0          602            1014         False
# 3              157.0           96            8570         False
# 4              331.0          274            1540         False
# ...              ...          ...             ...           ...
# 1995         33038.0         1024            8348         False
# 1996         33038.0         1024            8348         False
# 1997           634.0          192             514         False
# 1998         33038.0         1024            8348         False
# 1999         33038.0         1024            8348         False
#
#                     date                                               text  \
# 0    2021-02-05 10:58:03  $juld $bnb Binance BSC BinanceSmartChain BTC B...
# 1    2021-02-05 11:05:17  We are gaining pace with more and more institu...
# 2    2021-02-05 11:08:30  To-do or not To-do.   crypto btc Bitcoin Ether...
# 3    2021-02-05 11:10:39    Node for Bitcoin \n\nblockchain BTC /Oz4QGx769e
# 4    2021-02-05 11:17:53  bitcoin ATH is ~2x since last ATH. CARDANO ADA...
# ...                  ...                                                ...
# 1995 2021-02-08 18:33:57  FreeBitcoin  Bitcoin BTC Bitcoinmining ElonMus...
# 1996 2021-02-08 18:34:04  FreeBitcoin  Bitcoin BTC Bitcoinmining ElonMus...
# 1997 2021-02-08 18:34:10  TOTAL $BTC $ALT CRYPTOCAP \n\nI really nailed ...
# 1998 2021-02-08 18:34:10  FreeBitcoin  Bitcoin BTC Bitcoinmining ElonMus...
# 1999 2021-02-08 18:34:18  FreeBitcoin  Bitcoin BTC Bitcoinmining ElonMus...
#
#                                                hashtags               source  \
# 0     ['binance', 'bsc', 'binancesmartchain', 'btc',...  Twitter for Android
# 1                                           ['bitcoin']  Twitter for Android
# 2              ['crypto', 'btc', 'bitcoin', 'ethereum']   Twitter for iPhone
# 3                      ['bitcoin', 'blockchain', 'btc']   Twitter for iPhone
# 4     ['bitcoin', 'ath', 'ath', 'cardano', 'ada', 'a...   Twitter for iPhone
# ...                                                 ...                  ...
# 1995  ['freebitcoin', 'bitcoin', 'btc', 'bitcoinmini...  Twitter for Android
# 1996  ['freebitcoin', 'bitcoin', 'btc', 'bitcoinmini...  Twitter for Android
# 1997          ['cryptocap', 'btc', 'bitcoin', 'crypto']   Twitter for iPhone
# 1998  ['freebitcoin', 'bitcoin', 'btc', 'bitcoinmini...  Twitter for Android
# 1999  ['freebitcoin', 'bitcoin', 'btc', 'bitcoinmini...  Twitter for Android
#
#      is_retweet
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 1995      False
# 1996      False
# 1997      False
# 1998      False
# 1999      False
#
# [2000 rows x 13 columns]

# %%
from transformers import pipeline
import pandas as pd

# Sample DataFrame with 'text' column containing the small texts

# Create a sentiment analysis pipeline using transformers
sentiment_analyzer = pipeline("text-classification", model="ProsusAI/finbert")
#sentiment_analyzer = pipeline('sentiment-analysis')
# Function to get sentiment using transformers
def get_sentiment(text):
    sentiment = sentiment_analyzer(text)[0]
    return sentiment['label'], sentiment['score']

# Use tqdm to display a progress bar while applying the sentiment analysis function
tqdm.pandas()

# Add new columns 'sentiment_label' and 'sentiment_score' to the DataFrame
df4['sentiment_label'], df4['sentiment_score'] = zip(*df4['text'].progress_apply(get_sentiment))

print(df4.head())
# Out:
# 100%|██████████| 2000/2000 [01:04<00:00, 30.90it/s]
#           user_name user_location  \
# 0     Youssef Fedda     Australia
# 1           Zapumal       Colombo
# 2         EM_CryPT0     Nederland
# 3     Mr Fulcanelli     Argentina
# 4      Cardano Apps           NaN
# ...             ...           ...
# 1995   Free Bitcoin           NaN
# 1996   Free Bitcoin           NaN
# 1997      xbt_blvrg           NaN
# 1998   Free Bitcoin           NaN
# 1999   Free Bitcoin           NaN
#
#                                        user_description         user_created  \
# 0     love interesting startups, stocks and innovati...  2021-01-13 07:16:35
# 1     NUS PhD, Lecturer at CSE, Consultant Xeptagon....  2009-06-01 09:06:54
# 2     ▪️@CryptoBrothers5 Team ▪️💯% #Crypto▪️#BTC ▪️N...  2010-07-12 17:04:23
# 3                 be decentralized, be a smart contract  2010-08-23 20:41:38
# 4     CardanoApps - Discover new decentralised apps ...  2020-07-25 16:10:17
# ...                                                 ...                  ...
# 1995  #FreeBitcoin  #Bitcoin #BTC #Bitcoinmining #El...  2018-08-10 06:29:19
# 1996  #FreeBitcoin  #Bitcoin #BTC #Bitcoinmining #El...  2018-08-10 06:29:19
# 1997              I trade crypto futures and flip #BTC.  2011-11-09 16:38:56
# 1998  #FreeBitcoin  #Bitcoin #BTC #Bitcoinmining #El...  2018-08-10 06:29:19
# 1999  #FreeBitcoin  #Bitcoin #BTC #Bitcoinmining #El...  2018-08-10 06:29:19
#
#       user_followers user_friends user_favourites user_verified  \
# 0             2520.0         1085             191         False
# 1              290.0           58             569         False
# 2            16100.0          602            1014         False
# 3              157.0           96            8570         False
# 4              331.0          274            1540         False
# ...              ...          ...             ...           ...
# 1995         33038.0         1024            8348         False
# 1996         33038.0         1024            8348         False
# 1997           634.0          192             514         False
# 1998         33038.0         1024            8348         False
# 1999         33038.0         1024            8348         False
#
#                     date                                               text  \
# 0    2021-02-05 10:58:03  $juld $bnb Binance BSC BinanceSmartChain BTC B...
# 1    2021-02-05 11:05:17  We are gaining pace with more and more institu...
# 2    2021-02-05 11:08:30  To-do or not To-do.   crypto btc Bitcoin Ether...
# 3    2021-02-05 11:10:39    Node for Bitcoin \n\nblockchain BTC /Oz4QGx769e
# 4    2021-02-05 11:17:53  bitcoin ATH is ~2x since last ATH. CARDANO ADA...
# ...                  ...                                                ...
# 1995 2021-02-08 18:33:57  FreeBitcoin  Bitcoin BTC Bitcoinmining ElonMus...
# 1996 2021-02-08 18:34:04  FreeBitcoin  Bitcoin BTC Bitcoinmining ElonMus...
# 1997 2021-02-08 18:34:10  TOTAL $BTC $ALT CRYPTOCAP \n\nI really nailed ...
# 1998 2021-02-08 18:34:10  FreeBitcoin  Bitcoin BTC Bitcoinmining ElonMus...
# 1999 2021-02-08 18:34:18  FreeBitcoin  Bitcoin BTC Bitcoinmining ElonMus...
#
#                                                hashtags               source  \
# 0     ['binance', 'bsc', 'binancesmartchain', 'btc',...  Twitter for Android
# 1                                           ['bitcoin']  Twitter for Android
# 2              ['crypto', 'btc', 'bitcoin', 'ethereum']   Twitter for iPhone
# 3                      ['bitcoin', 'blockchain', 'btc']   Twitter for iPhone
# 4     ['bitcoin', 'ath', 'ath', 'cardano', 'ada', 'a...   Twitter for iPhone
# ...                                                 ...                  ...
# 1995  ['freebitcoin', 'bitcoin', 'btc', 'bitcoinmini...  Twitter for Android
# 1996  ['freebitcoin', 'bitcoin', 'btc', 'bitcoinmini...  Twitter for Android
# 1997          ['cryptocap', 'btc', 'bitcoin', 'crypto']   Twitter for iPhone
# 1998  ['freebitcoin', 'bitcoin', 'btc', 'bitcoinmini...  Twitter for Android
# 1999  ['freebitcoin', 'bitcoin', 'btc', 'bitcoinmini...  Twitter for Android
#
#      is_retweet sentiment_label  sentiment_score
# 0         False         neutral         0.825337
# 1         False        positive         0.800855
# 2         False         neutral         0.944352
# 3         False         neutral         0.936797
# 4         False         neutral         0.761649
# ...         ...             ...              ...
# 1995      False         neutral         0.940572
# 1996      False         neutral         0.939542
# 1997      False         neutral         0.885994
# 1998      False         neutral         0.941239
# 1999      False         neutral         0.935512
#
# [2000 rows x 15 columns]
# <ipython-input-92-7fd0213972b9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['sentiment_label'], df4['sentiment_score'] = zip(*df4['text'].progress_apply(get_sentiment))
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df4.to_pickle('sentiment.pkl')
